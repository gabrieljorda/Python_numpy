# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.3.5'

# %%
arr = np.array([1, 2, 3, 4, 5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
soma = arr +10

# %%
print("Array após somar 10 :",soma)
# Out:
# Array após somar 10 : [11 12 13 14 15]

# %%
multiplicacao = arr * 2 
print("Array após multiplicar por 2 :",multiplicacao)
# Out:
# Array após multiplicar por 2 : [ 2  4  6  8 10]

# %%
media = np.mean(arr)
print("Média dos elementos do array :",media)
# Out:
# Média dos elementos do array : 3.0

# %% [markdown]
# ### fim
